# %% [markdown]
# This Notebook Forward Propagates Seismic Images through VGG19 CNN and Compares Features Maps that are Most and Least Similar

# %%
# %% load VGG model and dependencies
# %load_ext autoreload
# %autoreload 2

#from keras.applications.vgg19 import VGG19
#from keras.applications.vgg19 import preprocess_input
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import Model
from keras.models import load_model
from keras.backend import clear_session

import matplotlib.pyplot as plt
from numpy import expand_dims

# %%
import os
os.chdir('..')
directory_path = os.getcwd()
directory_path
# Out:
# 'C:\\Users\\niven\\Documents\\~Python\\Seismic_Feature_Map'

# %%
# Import helper functions from utils folder
from src.definitions import ROOT_DIR
from src.data.utils import plot_image_compare, gen_feature_map, L2_norm, Filter_Activation_Sort

# %%
Model()

# %%
#Model weights and structure as VGG19 (may take a while to download)
model_dir = ROOT_DIR/'src/data/Unet_grayscale_True_pad_False_size_128.h5'
model = load_model(model_dir)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 8)  80          input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 8)  584         conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 8)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 16)   1168        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 16)   2320        conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 16)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   4640        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   9248        conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 64)   18496       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16, 16, 64)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 64)   36928       dropout[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 64)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 32)   8224        up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 64)   0           conv2d_5[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 32)   18464       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 32)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 16)   2064        up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 32)   0           conv2d_3[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 16)   4624        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 16)   2320        conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 16) 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 8)  520         up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 16) 0           conv2d_1[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 8)  1160        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 8)  584         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 1)  9           conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 1)  0           conv2d_17[0][0]
# ==================================================================================================
# Total params: 120,681
# Trainable params: 120,681
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Plot Seismic Images before Passing into Feature Mapping Scheme

# %%
from keras.utils.vis_utils import plot_model

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# Path for seismic images
impath1 = ROOT_DIR / 'src/data/0be5323c3b.png'
impath2 = ROOT_DIR / 'src/data/00cdefa5d6.png'
assert impath1.exists()
impath1
impath2
# Out:
# WindowsPath('C:/Users/niven/Documents/~Python/Seismic_Feature_Map/src/data/00cdefa5d6.png')

# %%
#Convert seismic images to arrays
img_size = (128,128)
img1 = img_to_array(load_img(impath1,color_mode = 'grayscale', target_size=img_size))/255
img2 = img_to_array(load_img(impath2,color_mode = 'grayscale', target_size=img_size))/255

# %%
img1.shape
# Out:
# (128, 128, 1)

# %%
# View seismic images
fig, ax = plt.subplots(1, 2, figsize=(10,5), facecolor=(0.98,0.97,0.94,1))
ax = plt.subplot(1, 2, 1)
ax.set_xticks([])
ax.set_yticks([])
ax.title.set_text('Seismic Image 1')
plt.imshow(img1, cmap='gray')
ax = plt.subplot(1, 2, 2)
ax.set_xticks([])
ax.set_yticks([])
ax.title.set_text('Seismic Image 2')
plt.imshow(img2, cmap='gray')
fig.suptitle('Seismic Image Comparison', fontsize=14)
# Out:
# Text(0.5, 0.98, 'Seismic Image Comparison')

# %% [markdown]
# Looking at the two seimic images below, an experienced interpreter would pretty quickly home in on key features like angular truncations, offset reflectors, bright spots, and noise zones for example.

# %% [markdown]
# Generate Feature Maps at Shallow Layer in the VGG19 Network

# %%
clear_session()
model = load_model(model_dir)

# %%
# Feature Maps at VGG19 Layer 2
#model, layer_out, image_in, target_size, grayscale)
layer_out = 12
model = Model(inputs=model.inputs, outputs=model.layers[layer_out].output)

feature_map1 = gen_feature_map(model, layer_out, impath1, target_size=img_size, color_mode='grayscale')

feature_map2 = gen_feature_map(model, layer_out, impath2, target_size=img_size, color_mode='grayscale')

#Caculate the similarity between feature maps using euclidean distance
cutoff_minimum_activation=10 #don't display feature maps of low activation

filters_similar, filters_different = Filter_Activation_Sort(feature_map1, feature_map2, cutoff_minimum_activation)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000155C0B67558> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 128, 8)       80
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 8)       584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 16)        1168
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 16)        2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 64)        36928
# =================================================================
# Total params: 73,464
# Trainable params: 73,464
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Plot Similar Feature Maps
chart_title = f'Filter Layer {layer_out}, Similar Features'
plot_image_compare(feature_map1, feature_map2, img1, img2, filters_similar, chart_title)
# Out:
# C:\Users\niven\Documents\~Python\Seismic_Feature_Map\src\data\utils.py:24: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(2, col_subplots, 1)
# C:\Users\niven\Documents\~Python\Seismic_Feature_Map\src\data\utils.py:35: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(2, col_subplots, 1+col_subplots)

# %%
#Plot Different Feature Maps
chart_title = f'Filter Layer {layer_out}, Different Features'
plot_image_compare(feature_map1, feature_map2, img1, img2, filters_different, chart_title)

# %% [markdown]
# Consider how Seismic Image 1 and Seismic Image 2 above may be interpreted through the eyes of a deep neural network in the figures above. Of the 64 features extracted shallow in the network, the two images share both similar and different activations, quantifying the comparision between them.

# %% [markdown]
# Generate Feature Maps at Middle Layer in the VGG19 Network

# %%
clear_session()
model = load_model(model_dir)

# %%
# Feature Maps at VGG19 Layer 2
layer_out = 13
model = Model(inputs=model.inputs, outputs=model.layers[layer_out].output)

feature_map1 = gen_feature_map(model, layer_out, impath1, target_size=img_size, color_mode='grayscale')

feature_map2 = gen_feature_map(model, layer_out, impath2, target_size=img_size, color_mode='grayscale')

#Caculate the similarity between feature maps using euclidean distance
cutoff_minimum_activation=5 #don't display feature maps of low activation

filters_similar, filters_different = Filter_Activation_Sort(feature_map1, feature_map2, cutoff_minimum_activation)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 128, 8)       80
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 8)       584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 16)        1168
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 16)        2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 32, 32, 64)        0
# =================================================================
# Total params: 73,464
# Trainable params: 73,464
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Plot Similar Feature Maps
chart_title = f'Filter Layer {layer_out}, Similar Features'
plot_image_compare(feature_map1, feature_map2, img1, img2, filters_similar, chart_title)
# Out:
# C:\Users\niven\Documents\~Python\Seismic_Feature_Map\src\data\utils.py:24: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(2, col_subplots, 1)
# C:\Users\niven\Documents\~Python\Seismic_Feature_Map\src\data\utils.py:35: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(2, col_subplots, 1+col_subplots)

# %%
#Plot Different Feature Maps
chart_title = f'Filter Layer {layer_out}, Different Features'
plot_image_compare(feature_map1, feature_map2, img1, img2, filters_different, chart_title)

# %% [markdown]
# Generate Feature Maps at Deep Layer in the VGG19 Networkb

# %%
clear_session()
model = load_model(model_dir)

# %%
# Feature Maps at VGG19 Layer 2
layer_out = 4
model = Model(inputs=model.inputs, outputs=model.layers[layer_out].output)

feature_map1 = gen_feature_map(model, layer_out, impath1, target_size=img_size, color_mode='grayscale')

feature_map2 = gen_feature_map(model, layer_out, impath2, target_size=img_size, color_mode='grayscale')

#Caculate the similarity between feature maps using euclidean distance
cutoff_minimum_activation=5 #don't display feature maps of low activation

filters_similar, filters_different = Filter_Activation_Sort(feature_map1, feature_map2, cutoff_minimum_activation)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 128, 8)       80
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 8)       584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 16)        1168
# =================================================================
# Total params: 1,832
# Trainable params: 1,832
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Plot Similar Feature Maps
chart_title = f'Filter Layer {layer_out}, Similar Features'
plot_image_compare(feature_map1, feature_map2, img1, img2, filters_similar, chart_title)
# Out:
# C:\Users\niven\Documents\~Python\Seismic_Feature_Map\src\data\utils.py:24: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(2, col_subplots, 1)
# C:\Users\niven\Documents\~Python\Seismic_Feature_Map\src\data\utils.py:35: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(2, col_subplots, 1+col_subplots)

# %%
#Plot Different Feature Maps
chart_title = f'Filter Layer {layer_out}, Different Features'
plot_image_compare(feature_map1, feature_map2, img1, img2, filters_different, chart_title)

# %% [markdown]
# While even a novice interpreter would be able to compare and contrast the two seismic images, the neural network has quantitatively encoded more features at all scales, further setting the stage for statistical analysis and input into machine learning algorithms. While an interpreter is always needed to determine what an image means, the neural network provides additional, less biased tools to identify key features, quantify seismic characteristics, and ultimately de-risk prospect inventories and help safely plan and drill wells.
